# %% [markdown]
# ## **The AI powered Financial Chatbot Prototype currently responds only to the given set of questions for selected companies and fiscal years wiz: --**
#
# 1.What is the total revenue?
# 2.What is the Net Income?
# 3.What is the sum of total assets?
# What is the sum of total liabilities?
# What is cash flow from operating activities?
# What is the revenue growth(%) ?
# What is the net income growth(%) ?
# What is the assets growth(%) ?
# What is the liabilities growth(%) ?
# What is the cash flow from operations growth(%) ?
# What is the year by year average revenue growth rate(%)?
# What is the year by year average net income growth rate(%)?
# What is the year by year average assets growth rate(%)?
# What is the year by year average liabilities growth rate(%)?
# What is the year by year average cash flow from operations growth rate(%)?

# %%
import pandas as pd
data1 = pd.read_csv('final_financial_data_report.csv')
data2 = pd.read_csv('year_by_year_summary_report.csv')

# %%
data1
# Out:
#    Year  Total Revenue  Net Income  Total Assets  Total Liabilities  \
# 0  2023         211915       72361        411976             205753
# 1  2022         198270       72738        364840             198298
# 2  2021         168088       61271        333779             191791
# 3  2023          96773       14974        106618              43009
# 4  2022          81462       12556         82338              36440
# 5  2021          53821        5519         62131              30548
# 6  2023         383285       96995        352583             290437
# 7  2022         394328       99803        352755             302083
# 8  2021         365817       94680        351002             287912
#
#    Cash Flow from Operating Activities    Company  Revenue Growth (%)  \
# 0                                87582  Microsoft            0.000000
# 1                                89035  Microsoft           -6.438902
# 2                                76740  Microsoft          -15.222676
# ...

# %%
print("Year by Year Average Growth from 2021 to 2023")
data2
# Out:
# Year by Year Average Growth from 2021 to 2023
#      Company  Year  Revenue Growth (%)  Net Income Growth (%)  \
# 0      Apple  2021           -7.230275              -5.133112
# 1      Apple  2022            2.881146               2.894995
# 2      Apple  2023            0.000000               0.000000
# 3  Microsoft  2021          -15.222676             -15.764800
# 4  Microsoft  2022           -6.438902               0.520999
# 5  Microsoft  2023            0.000000               0.000000
# 6      Tesla  2021          -33.931158             -56.044919
# 7      Tesla  2022          -15.821562             -16.147990
# 8      Tesla  2023            0.000000               0.000000
#
#    Assets Growth (%)  Liabilities Growth (%)  Cash Flow Growth (%)
# 0          -0.496945               -4.691095            -14.828368
# 1           0.048783                4.009820             10.500891
# 2           0.000000                0.000000              0.000000
# ...

# %%
# %run financial chatbot prototype.py
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/Library/Python/3.12/lib/python/site-packages/IPython/core/magics/execution.py:716, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     715     fpath = arg_lst[0]
# --> 716     filename = file_finder(fpath)
#     717 except IndexError as e:
#
# File ~/Library/Python/3.12/lib/python/site-packages/IPython/utils/path.py:91, in get_py_filename(name)
#      90         return py_name
# ---> 91 raise IOError("File `%r` not found." % name)
#
# OSError: File `'financial'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 get_ipython().run_line_magic('run', 'financial chatbot prototype.py')
#
# ...
